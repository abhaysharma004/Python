# %% [markdown]
# <a href="https://colab.research.google.com/github/abhaysharma004/Python/blob/main/Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.random.seed(1)

# %%
# 1000 random integers b/w 0 & 50
x=np.random.randint(0,50,1000)

# %%
y= x + np.random.normal(0, 10, 1000)
#positive correlation with some noise
y = x + np.random.normal(0, 10, 1000)

# %%
np.corrcoef(x , y)
# Out:
# array([[1.        , 0.81236628],
#        [0.81236628, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib Inline
matplotlib.style.use('ggplot')

plt.scatter(x, y)
plt.show()

# %%
y= x - np.random.normal(0, 10, 1000)
#positive correlation with some noise
y = x - np.random.normal(0, 10, 1000)

# %%
np.corrcoef(x , y)
# Out:
# array([[1.        , 0.83103233],
#        [0.83103233, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib Inline
matplotlib.style.use('ggplot')

plt.scatter(x, y)
plt.show()

# %%
y=100-x + np.random.normal(0, 10, 1000)
np.corrcoef(x , y)
# Out:
# array([[ 1.        , -0.79479891],
#        [-0.79479891,  1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib Inline
matplotlib.style.use('ggplot')

plt.scatter(x, y)
plt.show()

# %%
z=200-x + np.random.normal(0, 10, 1000)
np.corrcoef(x , z)
# Out:
# array([[ 1.        , -0.80679006],
#        [-0.80679006,  1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib Inline
matplotlib.style.use('ggplot')
plt.scatter(x, z)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib Inline
matplotlib.style.use('ggplot')

plt.scatter(y, z)
plt.show()

# %%
import pandas as pd
df = pd.DataFrame({'a': np.random.randint(0, 50,1000)})
df['b'] = df['a'] + np.random.normal(0,10,1000)
df['c'] = 100-df['a'] + np.random.normal(0,5,1000)
df['d'] = np.random.randint(0,50,1000)

df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.816709 -0.940753  0.044967
# b  0.816709  1.000000 -0.768035  0.049161
# c -0.940753 -0.768035  1.000000 -0.049715
# d  0.044967  0.049161 -0.049715  1.000000

# %%
pd.plotting.scatter_matrix(df,figsize=(6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)),df.columns)
plt.yticks(range(len(df.columns)),df.columns)
plt.colorbar()
plt.show()
